# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#plotting a simple graph
x = [2, 4, 5, 8, 10]
y = [5, 10, 15, 20, 25]
plt.plot(x,y)
plt.show()

# %%
#colour a graph
x = [2, 4, 5, 8, 10]
y = [5, 10, 15, 20, 25]
plt.plot(x,y,color='green')

# %%
#Mark points in graph
x = [2, 4, 5, 8, 10]
y = [5, 10, 15, 20, 25]
plt.plot(x,y,marker='*')

# %%
#mark point size, color, linestyle
plt.plot(x,y,marker='*',linestyle='--',markeredgecolor='yellow',markersize=10)

# %%
#Shortcut to all this in order manner
plt.plot(x,y,'r*--')

# %%
plt.plot(x,y,'r*--')
plt.title('Heading1',fontdict={'fontname':'Comic Sans MS', 'fontsize':20})
# Out:
# Text(0.5, 1.0, 'Heading1')

# %%
plt.plot(x,y,'r*--')
plt.title('first graph',fontdict={'fontname':'Comic Sans MS', 'fontsize':20})
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
plt.plot(x,y,'b*--')
plt.legend(['Single element'])
plt.show()

# %% [markdown]
# plt.plot(x,y,'b*--')
# plt.savefig('first graph.png',dpi=200)

# %% [markdown]
# # Let's make a Histogram Graph

# %% [markdown]
# Pie-Chart

# %%
#Ploting Pie-Chart Graph
hey = np.array([25, 30, 35, 40])
name = ["Ajay", "Vijay", "Suresh", "Sanjay"]

plt.pie(hey,labels=name,)
plt.show()

# %%
#Explode
nameexplode = [0,0,0,0.2]
plt.pie(hey,labels=name,explode=nameexplode,shadow=True)
plt.show()

# %%
#Box plot 
test = np.random.normal(200,50,400)
plt.boxplot(test)
plt.show()

# %%
#Multiple Box plot
test1 = np.random.normal(200,50,400)
test2 = np.random.normal(100,50,300)
test3 = np.random.normal(150,100,400)
test4 = np.random.normal(250,75,400)
test = [test1,test2,test3,test4]
plt.boxplot(test)
plt.show()

# %% [markdown]
# Scatter plot

# %%
x = [1,2,4,8,5,6]
y = [5,6,7,8,9,8]
plt.scatter(x,y)
plt.show()
